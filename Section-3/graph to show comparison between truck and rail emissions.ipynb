# %%
import matplotlib.pyplot as plt

# %%
# Plot with corrected color names
fig, ax = plt.subplots(figsize=(8, 6))

# Truck emissions will be light blue, rail emissions will be orange
bar1 = ax.bar(index, truck_emissions, bar_width, color='lightblue', label='Truck emissions (kg CO2e)')
bar2 = ax.bar([i + bar_width for i in index], rail_emissions, bar_width, color='orange', label='Rail emissions (kg CO2e)')

# Adding labels, title, and legend
ax.set_xlabel('Emission Source')
ax.set_ylabel('Emissions (kg CO2e)')
ax.set_title('Comparison between truck and rail emissions by source (Updated)')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(categories)
ax.legend()

# Displaying the plot
plt.tight_layout()
plt.show()
